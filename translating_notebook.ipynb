# %%
import os
import openai
from dotenv import load_dotenv

# %%
# Set your OpenAI API key
#load_dotenv()
openai.api_key = "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"
print(openai.api_key)
#openai.api_key = 'your-openai-api-key'
 
# Folder containing the text files
folder_path = 'C:/Users/hussa/OneDrive - KU Leuven/Datathon/dutch'
 
# Function to call ChatGPT API
def call_chatgpt_api(text):
    prompt = f"This is a computer vision reading of a WW1 poster in Belgium. Correct the irregularities that may be present and translate it to English. The translation should be a string and the only output of the prompt.\n\n{text}"
 
    response = openai.ChatCompletion.create(
        model="gpt-4o",  # or "gpt-3.5-turbo" if you prefer
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
 
    # Extract the translated text from the response
    translated_text = response['choices'][0]['message']['content'].strip()
    return translated_text
 
# Iterate through text files in the folder
for filename in os.listdir(folder_path):

    if filename.endswith('.txt'):
        file_path = os.path.join(folder_path, filename)
        # Read the content of the text file
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()

        # Call the ChatGPT API
        translated_text = call_chatgpt_api(text)

        # Print or save the translated text
        print(f"Translated text from {filename}:\n{translated_text}\n")

        output_folder_path = 'C:/Users/hussa/OneDrive - KU Leuven/Datathon/translateddocs'
        # Optionally, save the translated text to a new file
        output_file_path = os.path.join(output_folder_path, f"translated_{filename}")
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            output_file.write(translated_text)
            print(f"Translated text saved to {output_file_path}\n")

    print("Translation process completed.")
# Out:
# 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
# Translated text from FL4984787_1_DIGI_0035_00001_VIEW_MAIN.jpg.txt:
# Announcements from the German General Government.
#
# The "Matin" of Paris writes on May 1915
#
# A TRUE STORY.
#
# How to get rid of a troublesome journalist.
#
# "The reign of terror that the cruel Germans have now imposed for nearly nine months in unfortunate Belgium has found a new victim in the person of Mr. Joset, a newspaper editor from the province of Luxembourg, a man of great merit who played a significant political role in his province up until the outbreak of war.
#
# ...
